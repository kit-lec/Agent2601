# %%
print("Hello Python")
# Out:
# Hello Python

# %%
print('AI 활용 MCP Agent')
# Out:
# AI 활용 MCP Agent

# %%
print("Good Morning")
print(1000)
print(55 - 102)
# Out:
# Good Morning
# 1000
# -47

# %%
print("Good Morning")
print(1000)
print(55 - 102)
# Out:
# Good Morning
# 1000
# -47

# %% [markdown]
# "행 삽입, 행 삭제"

# %% [markdown]
# 이것은 텍스트 셀입니다

# %% [markdown]
# 안녕하세요

# %%
"Hello Python"
# Out:
# 'Hello Python'

# %%
100 + 200
# Out:
# 300

# %%
print("Good Morning")
print(1000)
print(55 - 102)
# Out:
# Good Morning
# 1000
# -47

# %%
# 프로그램에 메모할게 있다면 '주석' 처리
# 동해물과
# 백두산이
# 마르고
# 닳도록

# %%
print(100)
print(200)
print(300)
print(400)
# Out:
# 100
# 200
# 300
# 400

# %%
#  '/' slash
#  '\' back-slash
