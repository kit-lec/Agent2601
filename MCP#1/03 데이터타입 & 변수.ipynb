# %% [markdown]
# # 숫자(정수, 실수) 데이터
# - int
# - float

# %%
print(10)   # 정수 int
print(10.0) # 실수 float
print(10.)  # 10.0
print(.1)   # 0.1
# Out:
# 10
# 10.0
# 10.0
# 0.1

# %%
10 - 2
# Out:
# 8

# %%
10 - 2 * 4
# Out:
# 2

# %%
(10 - 2) * 4
# Out:
# 32

# %%
# 정수와 정수끼리의 연산결과는 정수(int)
# 실수와의 연산결과는 실수(float)

4 * 5
# Out:
# 20

# %%
4 * 5.0
# Out:
# 20.0

# %%
4 / 2  # 나눗셈(/) 연산결과는 언제나 실수!
# Out:
# 2.0

# %%
# 나눗셈 후 소수점 이하를 버리는 연산자 :  //
# 정수 끼리 딱 떨어지는 결과에 대해서는 정수로 결과가 나옴

4 // 2
# Out:
# 2

# %%
4 // 2.0
# Out:
# 2.0

# %%
5 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2219314525.py in <cell line: 0>()
# ----> 1 5 / 0
#
# ZeroDivisionError: division by zero

# %%
# 나머지 연산자 %

13 % 3
# Out:
# 1

# %%
12.5 % 4.1  #  12.5 = 4.1 * 3 + 0.2
# Out:
# 0.20000000000000107

# %%
# ★★컴퓨터의 실수 계산결과는 오차가 존재할수 있다!

# %%
# 제곱연산자 **

2 ** 4
# Out:
# 16

# %%
-3 ** 3
# Out:
# -27

# %%
2 ** -1
# Out:
# 0.5

# %%
2 ** -2
# Out:
# 0.25

# %%
2 ** (1/2)
# Out:
# 1.4142135623730951

# %% [markdown]
# # 문자열 str
# string

# %%
#----------------------------------
# 문자열 타입 : str (string)
# 문자열 리터럴 만드는 방법
# 1. 쌍따옴표 (double quotation)
# 2. 홀따옴표 (single quotation)
# 3. 쌍따옴표3개
# 4. 홀따옴표3개
# 그밖에
#   f-string
#   r-string
#   ..///

# %%
"Python"
# Out:
# 'Python'

# %%
'Python'
# Out:
# 'Python'

# %%
"""Python"""
# Out:
# 'Python'

# %%
'''Python'''
# Out:
# 'Python'

# %%
"She's gone"
# Out:
# "She's gone"

# %%
# 'She's gone'

# %%
"Python is fun"
# Out:
# 'Python is fun'

# %%
# "Python
# is fun"

# %%
"""Python is fun"""
# Out:
# 'Python is fun'

# %%
print("""Python
 is fun""")
# Out:
# Python
#  is fun

# %%
# 문자열 연결 연산 +
"Hello" + "World"
# Out:
# 'HelloWorld'

# %%
# 문자열 반복 연산 *
"Hello" * 3
# Out:
# 'HelloHelloHello'

# %%
# len() : 문자열 안의 문자개수
len("Python")
# Out:
# 6

# %%
len("안녕하세요 Python")
# Out:
# 12

# %% [markdown]
# # bool타입
# boolean
# - `True`(참) 혹은 `False`(거짓) 값만 갖는 논리 타입

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
# true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-592217714.py in <cell line: 0>()
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
# 비교연산자(들)
# >, <, >=, <=, ==, !=
# 연산결과는 bool 타입

print(20 > 10)
print(20 < 10)
print(20 >= 20)
print(20 < 20)
print(20 <= 20)
print(20 == 20)
print(20 != 20)
# Out:
# True
# False
# True
# False
# True
# True
# False

# %%
5.0 == 5
# Out:
# True

# %%
10 / 2 == 5
# Out:
# True

# %%
2.1 + 0.2 == 2.3
# Out:
# False

# %%
2.1 + 0.2
# Out:
# 2.3000000000000003

# %% [markdown]
# # None 타입
# 아무런 값도 없는 데이터타입

# %%
None

# %%
print(None)
# Out:
# None

# %% [markdown]
# # type() 함수

# %%
type(10)
# Out:
# int

# %%
type(10.0)
# Out:
# float

# %%
type("10.0")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(None)
# Out:
# NoneType

# %% [markdown]
# # 🟦 변수 (Variable)

# %%
# 변수(variable) 은 데이터를 담아두는 공간
# 이름을 정해서 담아둔다.  이 이름을 변수이름 (variable name) 이라한다
# 변수의 데이터는 언제든지 변경할수 있다. (변할수 있다!)

# 변수 사용법
#  변수명 = 값

# 이와 같이 = 연산자를 사용하여 변수에 값을 저장하는 것을 대입(assign 한다 라고 하며
# = 을 대입연산자 (assignment operator) 라고 한다

# ★★프로그래머는 변수에 어떠한 '타입'의 어떠한 '값'이 담겨 있는지 놓치면 안된다!   타입! 값!

# 변수명은 대소문자 구분한다

# %%
a = 10  # a라는 변수에 정수 int 값 10을 대입 (저장, 쓰기)

# %%
a  # a라는 변수의 값을 읽어옴 (읽기)
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
b = 5

# %%
b
# Out:
# 5

# %%
a + b
# Out:
# 15

# %%
print(100, 200, 300)
# Out:
# 100 200 300

# %%
print(a, b, a + b, a - b)
# Out:
# 10 5 15 5

# %%
# print(c)  # NameError: name 'c' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2743823995.py in <cell line: 0>()
# ----> 1 print(c)
#
# NameError: name 'c' is not defined

# %%
# print(A)  # a 와 A 는 다르다
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-212384544.py in <cell line: 0>()
# ----> 1 print(A)
#
# NameError: name 'A' is not defined

# %% [markdown]
# ## type 변환 함수
# int(), float(), str(), bool() ....

# %%
my_name = '김만수'

# %%
print('제 이름은', my_name, '입니다')
print('제 이름은 ' + my_name + ' 입니다')
# Out:
# 제 이름은 김만수 입니다
# 제 이름은 김만수 입니다

# %%
age = 10

# %%
# age + "살"  # str 과 숫자간 + 연산 안됨!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2613272323.py in <cell line: 0>()
# ----> 1 age + "살"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(age) + "살"  # int -> str로 형변환한 결과
# Out:
# '10살'

# %%
num = "100"

# %%
# num + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1746008578.py in <cell line: 0>()
# ----> 1 num + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
int(num) + 2 # str -> int 로 형변환
# Out:
# 102

# %%
float("300")
# Out:
# 300.0

# %%
int(3.14)  # 실수 -> 정수 변환.  소숫점 이하 제거.
# Out:
# 3

# %%
bool(0)   # 0 --> False
# Out:
# False

# %%
bool(1)   # 0 이외의 숫자 --> True
# Out:
# True

# %%
int(False)   # False --> 0
# Out:
# 0

# %%
int(True)    # True --> 1
# Out:
# 1

# %% [markdown]
# ## del() : 변수 제거

# %%
name = "John"

name
# Out:
# 'John'

# %%
del(name)  # 변수 제거

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3474671970.py in <cell line: 0>()
# ----> 1 name
#
# NameError: name 'name' is not defined

# %% [markdown]
# ## 여러 변수 한줄에 선언

# %%
# 여러 변수를 한줄에 선언
a = 10
b = 20
c = 30
print(a, b, c)
# Out:
# 10 20 30

# %%
a, b, c = 10, 20, 30

print(a, b, c)
# Out:
# 10 20 30

# %% [markdown]
# ## 변수의 값 증감

# %%
a = 10
print(a)
a = a + 1
print(a)
a = a * 2
print(a)
# Out:
# 10
# 11
# 22

# %%
a, b, c = 100, 10, 7

# %%
# a = a + 10
a += 10   # 복합 대입 연산자
print(a)
# Out:
# 110

# %%
b /= 2
print(b)
# Out:
# 5.0

# %%
c %= 2   # c = c % 2
print(c)
# Out:
# 1

# %% [markdown]
# ## 변수 값 서로 바꾸기

# %%
a, b = 11, 33
print(a, b)

temp = a
a = b
b = temp

print(a, b)
# Out:
# 11 33
# 33 11

# %%
a, b = 11, 33
print(a, b)

a, b = b, a

print(a, b)
# Out:
# 11 33
# 33 11
