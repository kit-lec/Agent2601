# %% [markdown]
# # asyncio
# - 비동기 프로그래밍

# %% [markdown]
# # 동기 vs. 비동기

# %%
"""
동기(synchronous) 프로그래밍 과 비동기(asynchronous) 프로그래밍은
작업을 처리하고 결과를 기다리는 방식에 대한 개념


🌐 1. 동기 프로그래밍 (Synchronous Programming)
    개념:
      작업을 순차적으로 처리함.
      앞의 작업이 끝나야 다음 작업을 시작함.
      결과가 올 때까지 기다림.

    장점:
      디버깅이 상대적으로 쉬움.

    단점:
      '시간이 오래 걸리는 작업'이 있으면 전체 흐름이 멈춤.
        - ex) 네트워크/웹 통신 I/O, DB I/O, 파일 I/O 등..
      사용자 경험이 나쁠 수 있음 (예: UI 멈춤).

⚡ 2. 비동기 프로그래밍 (Asynchronous Programming)
    개념:
      작업을 백그라운드에서 처리하고, 나중에 결과가 도착하면 알림을 받음.
      기다리지 않고 다음 작업을 바로 실행함.

    장점:
      긴 작업 중에도 다른 작업을 동시에 수행할 수 있음.
      자원을 더 효율적으로 사용 가능 (특히 I/O 작업에 적합).

    단점:
      코드 흐름이 복잡해질 수 있음 (콜백 지옥, Promise 체인, async/await 등).
      디버깅이 어려움.

"""
None

# %% [markdown]
# ![](https://img1.daumcdn.net/thumb/R960x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2Fdgzxm2%2Fbtq6gMWpMoE%2FAAAAAAAAAAAAAAAAAAAAABdpsEMkrrNAXoEf7Hh7rDyboiJYSPqY1DKbm98t4qCl%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1756652399%26allow_ip%3D%26allow_referer%3D%26signature%3DwILMwelTLCas%252BObneLj5KYa0fd8%253D)
#
# ![](https://velog.velcdn.com/images%2Fdat0802%2Fpost%2F32583695-bf93-4d6e-856b-fe04e1cd2f1f%2F%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-03-18%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%203.36.46.png)

# %%
"""
파이썬 3.4에서 asyncio 모듈이 표준 라이브러리로 추가되면서 비동기 프로그래밍 가능

파이썬 3.5에서 async / await 키워드가 문법으로 채택이 되면서
  외부 라이브러리 없이도 비동기 프로그래밍이 가능해졌다.
"""
None

# %% [markdown]
# # import

# %%
import asyncio
import time

# %% [markdown]
# # async def

# %%
# async def 로 선언한 함수는 코루틴(coroutine) 을 리턴함.

async def hello():
  print('hello python!')

print(hello, type(hello))
hello()
# Out:
# <function hello at 0x7bf6c0258400> <class 'function'>
# <coroutine object hello at 0x7bf6d2319480>

# %%
# asyncio.run(hello())


await hello()
# Out:
# hello python!

# %% [markdown]
# # 1. 동기화된 time.sleep()

# %%
time.sleep(3)
print('3초 경과')
# Out:
# 3초 경과

# %%
def sync_work(icon, seconds=0):
  print(f'{icon} {seconds}초 작업 시작')
  start = time.time()  # 현재시간 저장 (단위 초)
  time.sleep(seconds)  # 시간이 걸리는 작업
  end = time.time()
  print(f"{icon} 작업종료: {end-start:.3f}초 소요")

# %%
def sync_all():
  sync_work('🍆', 3)
  sync_work('🍊', 1)
  sync_work('🥦', 2)

# 총 몇초의 시간이 걸릴것인가?
# 화면에 출력되는 순서는 어떻게 될것인가?

# %%
start = time.time()
sync_all()
end = time.time()
print(f'>>> 총 경과시간: {end - start:.3f}초')
# Out:
# 🍆 3초 작업 시작
# 🍆 작업종료: 3.000초 소요
# 🍊 1초 작업 시작
# 🍊 작업종료: 1.000초 소요
# 🥦 2초 작업 시작
# 🥦 작업종료: 2.000초 소요
# >>> 총 경과시간: 6.001초

# %% [markdown]
# # 2. 비동기 asyncio.sleep()

# %%
async def async_work(icon, seconds=0):
  print(f'{icon} {seconds}초 작업 시작')
  start = time.time()
  await asyncio.sleep(seconds)   # await 비동기 함수 호출 -> 비동기 함수가 끝날때까지 기다림. (blocking)
                              # await 는 반.드.시  async 비동기 함수내에서만 사용 가능!
  end = time.time()
  print(f'{icon} 작업종료: {end - start:.3f}초 소요')
  return f'{icon}-{seconds}작업'

# %%
await async_work('🤪', 4)
# Out:
# 🤪 4초 작업 시작
# 🤪 작업종료: 4.005초 소요
# '🤪-4작업'

# %%
async def async_all():
  task1 = asyncio.create_task(async_work('🍆', 3))  # Task 생성.  비동기 호출 시작됨.
  task2 = asyncio.create_task(async_work('🍊', 1))
  task3 = asyncio.create_task(async_work('🥦', 2))

  # await task1   # await Task. <- 비동기 Task 가 끝날때까지 기다림.
  # await task2
  # await task3

  result = await asyncio.gather(task1, task2, task3)  # gather() 는 각 비동기 작업의 리턴값들을 리턴
  return result

# %%
start = time.time()
result = await async_all()
end = time.time()
print(f'>>> 총 경과시간: {end - start:.3f}초')
print(result)
# Out:
# 🍆 3초 작업 시작
# 🍊 1초 작업 시작
# 🥦 2초 작업 시작
# 🍊 작업종료: 1.001초 소요
# 🥦 작업종료: 2.002초 소요
# 🍆 작업종료: 3.002초 소요
# >>> 총 경과시간: 3.003초
# ['🍆-3작업', '🍊-1작업', '🥦-2작업']
